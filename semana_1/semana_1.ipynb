# %%
students = [
    "João",
    "Fernando",
    "Júlia",
    "Maria",
    "André",
]

for student in students:
    print(student)
# Out:
# João
# Fernando
# Júlia
# Maria
# André

# %%
for student in students:
    print(f"ABC1_{student}")
# Out:
# ABC1_João
# ABC1_Fernando
# ABC1_Júlia
# ABC1_Maria
# ABC1_André

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Housing.csv')
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
for i, row in df.iterrows():
    if row["area"] > 5150.541284:
        print(f"house {i} is big")
    else:
        print(f"house {i} is small")
# Out:
# house 0 is big
# house 1 is big
# house 2 is big
# house 3 is big
# house 4 is big
# house 5 is big
# house 6 is big
# house 7 is big
# house 8 is big
# house 9 is big
# house 10 is big
# house 11 is big
# house 12 is big
# house 13 is small
# house 14 is big
# house 15 is big
# house 16 is big
# house 17 is big
# house 18 is small
# house 19 is big
# house 20 is small
# house 21 is big
# house 22 is big
# house 23 is small
# house 24 is big
# house 25 is big
# house 26 is big
# house 27 is big
# house 28 is big
# house 29 is big
# house 30 is big
# house 31 is big
# house 32 is small
# house 33 is big
# house 34 is big
# house 35 is big
# house 36 is big
# house 37 is big
# house 38 is big
# house 39 is big
# house 40 is big
# house 41 is big
# house 42 is big
# house 43 is big
# house 44 is big
# house 45 is big
# house 46 is big
# house 47 is big
# house 48 is small
# house 49 is big
# house 50 is big
# house 51 is big
# house 52 is big
# house 53 is small
# house 54 is big
# ...
